# %%
#.read_csv()
#.head()
#.columns
#display()
#pd.concat()
#.merge()
#.rename()
#.drop()
#.drop_duplicates()
#.to_numeric()
#.reset_index()
#.loc[]
#.iloc[]

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import scipy.stats as stats
import os #we will use the function listdir to list files in a folder
import math #to apply absolute value

from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score, mean_squared_error, mean_absolute_error

import warnings
warnings.filterwarnings('ignore')

# %%
data = pd.read_csv("fifa21_male2.csv")
data.head()
# Out:
#    ID         Name  Age  OVA            Nationality           Club  BOV   BP  \
# 0   2  G. Pasquale   33   69                  Italy        Udinese   71  LWB
# 1  16  Luis García   37   71                  Spain      KAS Eupen   70   CM
# 2  27      J. Cole   33   71                England  Coventry City   71  CAM
# 3  36     D. Yorke   36   68  Trinidad &amp; Tobago     Sunderland   70   ST
# 4  41      Iniesta   36   81                  Spain    Vissel Kobe   82  CAM
#
#        Position                                       Player Photo  ...  \
# 0            LM  https://cdn.sofifa.com/players/000/002/16_120.png  ...
# 1    CM CAM CDM  https://cdn.sofifa.com/players/000/016/19_120.png  ...
# 2  CAM RM RW LM  https://cdn.sofifa.com/players/000/027/16_120.png  ...
# 3           NaN  https://cdn.sofifa.com/players/000/036/09_120.png  ...
# 4        CM CAM  https://cdn.sofifa.com/players/000/041/20_120.png  ...
#
#      CDM    RDM    RWB     LB   LCB    CB   RCB     RB    GK Gender
# ...

# %%
data.shape
# Out:
# (17125, 107)

# %%
column_names = data.columns

list(column_names)
# Out:
# ['ID',
#  'Name',
#  'Age',
#  'OVA',
#  'Nationality',
#  'Club',
#  'BOV',
#  'BP',
#  'Position',
#  'Player Photo',
#  'Club Logo',
#  'Flag Photo',
#  'POT',
#  'Team & Contract',
#  'Height',
#  'Weight',
#  'foot',
#  'Growth',
#  'Joined',
#  'Loan Date End',
#  'Value',
#  'Wage',
#  'Release Clause',
#  'Contract',
#  'Attacking',
#  'Crossing',
#  'Finishing',
#  'Heading Accuracy',
#  'Short Passing',
#  'Volleys',
#  'Skill',
#  'Dribbling',
#  'Curve',
#  'FK Accuracy',
#  'Long Passing',
#  'Ball Control',
#  'Movement',
#  'Acceleration',
#  'Sprint Speed',
#  'Agility',
#  'Reactions',
#  'Balance',
#  'Power',
#  'Shot Power',
#  'Jumping',
#  'Stamina',
#  'Strength',
#  'Long Shots',
#  'Mentality',
#  'Aggression',
#  'Interceptions',
#  'Positioning',
#  'Vision',
#  'Penalties',
#  'Composure',
#  'Defending',
#  'Marking',
#  'Standing Tackle',
#  'Sliding Tackle',
#  'Goalkeeping',
#  'GK Diving',
#  'GK Handling',
#  'GK Kicking',
#  'GK Positioning',
# ...

# %%
data
# Out:
#            ID             Name  Age  OVA            Nationality  \
# 0           2      G. Pasquale   33   69                  Italy
# 1          16      Luis García   37   71                  Spain
# 2          27          J. Cole   33   71                England
# 3          36         D. Yorke   36   68  Trinidad &amp; Tobago
# 4          41          Iniesta   36   81                  Spain
# ...       ...              ...  ...  ...                    ...
# 17120  259088       A. Medioub   22   64                 France
# 17121  259090       W. Rickard   18   56                  Wales
# 17122  259091       C. Barrett   18   56                England
# 17123  259101   J. Gazibegović   20   62     Bosnia Herzegovina
# 17124  259105  Pablo Rodríguez   18   59                  Spain
#
#                 Club  BOV   BP      Position  \
# 0            Udinese   71  LWB            LM
# 1          KAS Eupen   70   CM    CM CAM CDM
# 2      Coventry City   71  CAM  CAM RM RW LM
# ...

# %% [markdown]
# ## renaming columns, rearranging columns,

# %%
# renaming columns
data.columns = data.columns.str.lower()
data = data.rename(columns={'BOV':'OVA':'BP':'POT':'W/F':'SM''A/W':'D/W':'IR':'PAC':'SHO':'PAS':'DRI':'DEF':'PHY':'Hits':'LS':'SRS''LW:'LF'
:'CF':'RF':'RW':'LAM':'CAM':'RAM':'LM':'LCM':'CM':'RCM':'RM':'LWB':'LDM':'CDM':'RDM':'RWB':'LB':'LCB':'CB':'RCB':'RB':'GK',
                            'BOV':'',
                            'OVA':'', 'BP':'','POT':'','W/F':'','SM':'','A/W':'','D/W':'','IR':'','PAC':'','SHO':'','PAS':'','DRI':'','DEF':'','PHY':'','Hits':'','LS':'','SRS':'','LW:'','LF':'',
'CF':'','RF':'','RW':'','LAM':'','CAM':'','RAM':'','LM':'','LCM':'','CM':'','RCM':'','RM':'','LWB':'','LDM':'','CDM':'','RDM':'','RWB':'','LB':'','LCB':'','CB':'','RCB':'','RB':'','GK':''})

display(data)
# Out:
#   File "C:\Users\samag\AppData\Local\Temp/ipykernel_7400/2864242581.py", line 3
#     data = data.rename(columns={'BOV':'OVA':'BP':'POT':'W/F':'SM''A/W':'D/W':'IR':'PAC':'SHO':'PAS':'DRI':'DEF':'PHY':'Hits':'LS':'SRS''LW:'LF'
#                                            ^
# SyntaxError: invalid syntax

# %% [markdown]
# # which column are categorical

# %%
data.drop(columns=data._get_numeric_data().columns).columns
# Out:
# Index(['Name', 'Nationality', 'Club', 'BP', 'Position', 'Player Photo',
#        'Club Logo', 'Flag Photo', 'Team & Contract', 'Height', 'Weight',
#        'foot', 'Joined', 'Loan Date End', 'Value', 'Wage', 'Release Clause',
#        'Contract', 'W/F', 'SM', 'A/W', 'D/W', 'IR', 'Hits', 'LS', 'ST', 'RS',
#        'LW', 'LF', 'CF', 'RF', 'RW', 'LAM', 'CAM', 'RAM', 'LM', 'LCM', 'CM',
#        'RCM', 'RM', 'LWB', 'LDM', 'CDM', 'RDM', 'RWB', 'LB', 'LCB', 'CB',
#        'RCB', 'RB', 'GK', 'Gender'],
#       dtype='object')

# %% [markdown]
# # Which columns are numerical

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17125 entries, 0 to 17124
# Columns: 107 entries, ID to Gender
# dtypes: float64(10), int64(45), object(52)
# memory usage: 14.0+ MB

# %%
data.dtypes
# Out:
# ID              int64
# Name           object
# Age             int64
# OVA             int64
# Nationality    object
#                 ...
# CB             object
# RCB            object
# RB             object
# GK             object
# Gender         object
# Length: 107, dtype: object

# %%
data._get_numeric_data()
# Out:
#            ID  Age  OVA  BOV  POT  Growth  Attacking  Crossing  Finishing  \
# 0           2   33   69   71   69       0        313        75         50
# 1          16   37   71   70   71       0        337        68         64
# 2          27   33   71   71   71       0        337        80         64
# 3          36   36   68   70   82      14        264        54         70
# 4          41   36   81   82   81       0        367        75         69
# ...       ...  ...  ...  ...  ...     ...        ...       ...        ...
# 17120  259088   22   64   66   69       5        197        35         23
# 17121  259090   18   56   58   66      10        248        50         43
# 17122  259091   18   56   56   67      11        218        55         34
# 17123  259101   20   62   62   73      11        223        62         26
# 17124  259105   18   59   61   74      15        254        32         64
#
#        Heading Accuracy  ...  GK Positioning  GK Reflexes  Total Stats  \
# ...

# %%
data.isna().sum()
# Out:
# ID             0
# Name           0
# Age            0
# OVA            0
# Nationality    0
#               ..
# CB             0
# RCB            0
# RB             0
# GK             0
# Gender         0
# Length: 107, dtype: int64

# %%
data.duplicated().sum()
# Out:
# 0

# %%
data.select_dtypes("object")
# Out:
#                   Name            Nationality           Club   BP  \
# 0          G. Pasquale                  Italy        Udinese  LWB
# 1          Luis García                  Spain      KAS Eupen   CM
# 2              J. Cole                England  Coventry City  CAM
# 3             D. Yorke  Trinidad &amp; Tobago     Sunderland   ST
# 4              Iniesta                  Spain    Vissel Kobe  CAM
# ...                ...                    ...            ...  ...
# 17120       A. Medioub                 France     CD Tondela   CB
# 17121       W. Rickard                  Wales        Burnley  CAM
# 17122       C. Barrett                England        Burnley   RB
# 17123   J. Gazibegović     Bosnia Herzegovina  SK Sturm Graz   RB
# 17124  Pablo Rodríguez                  Spain          Lecce   ST
#
#            Position                                       Player Photo  \
# 0                LM  https://cdn.sofifa.com/players/000/002/16_120.png
# ...

# %%
data.describe()
# Out:
#                   ID           Age           OVA           BOV           POT  \
# count   17125.000000  17125.000000  17125.000000  17125.000000  17125.000000
# mean   219388.716204     25.272934     66.965022     67.900204     72.489810
# std     37499.197507      4.942665      6.864329      6.637538      5.769949
# min         2.000000     16.000000     38.000000     42.000000     47.000000
# 25%    204082.000000     21.000000     62.000000     64.000000     69.000000
# 50%    228961.000000     25.000000     67.000000     68.000000     72.000000
# 75%    243911.000000     29.000000     72.000000     72.000000     76.000000
# max    259105.000000     53.000000     93.000000     93.000000     95.000000
#
#              Growth     Attacking      Crossing     Finishing  \
# count  17125.000000  17125.000000  17125.000000  17125.000000
# mean       5.524788    258.537752     51.621314     47.956672
# std        5.787539     72.255687     17.875715     19.391547
# ...

# %%
# deleting columns,

# %%
# Removing duplicates

# %%
data = data.drop_duplicates()
data
# Out:
#            ID             Name  Age  OVA            Nationality  \
# 0           2      G. Pasquale   33   69                  Italy
# 1          16      Luis García   37   71                  Spain
# 2          27          J. Cole   33   71                England
# 3          36         D. Yorke   36   68  Trinidad &amp; Tobago
# 4          41          Iniesta   36   81                  Spain
# ...       ...              ...  ...  ...                    ...
# 17120  259088       A. Medioub   22   64                 France
# 17121  259090       W. Rickard   18   56                  Wales
# 17122  259091       C. Barrett   18   56                England
# 17123  259101   J. Gazibegović   20   62     Bosnia Herzegovina
# 17124  259105  Pablo Rodríguez   18   59                  Spain
#
#                 Club  BOV   BP      Position  \
# 0            Udinese   71  LWB            LM
# 1          KAS Eupen   70   CM    CM CAM CDM
# 2      Coventry City   71  CAM  CAM RM RW LM
# ...

# %%
pd.set_option('display.max_columns', None)
#pd.set_option('display.max_rows', None)
data.head()
#data.describe()
# Out:
#    ID         Name  Age  OVA            Nationality           Club  BOV   BP  \
# 0   2  G. Pasquale   33   69                  Italy        Udinese   71  LWB
# 1  16  Luis García   37   71                  Spain      KAS Eupen   70   CM
# 2  27      J. Cole   33   71                England  Coventry City   71  CAM
# 3  36     D. Yorke   36   68  Trinidad &amp; Tobago     Sunderland   70   ST
# 4  41      Iniesta   36   81                  Spain    Vissel Kobe   82  CAM
#
#        Position                                       Player Photo  \
# 0            LM  https://cdn.sofifa.com/players/000/002/16_120.png
# 1    CM CAM CDM  https://cdn.sofifa.com/players/000/016/19_120.png
# 2  CAM RM RW LM  https://cdn.sofifa.com/players/000/027/16_120.png
# 3           NaN  https://cdn.sofifa.com/players/000/036/09_120.png
# 4        CM CAM  https://cdn.sofifa.com/players/000/041/20_120.png
#
#                                           Club Logo  \
# ...

# %%
data.columns
print(data.columns.tolist())
# Out:
# ['ID', 'Name', 'Age', 'OVA', 'Nationality', 'Club', 'BOV', 'BP', 'Position', 'Player Photo', 'Club Logo', 'Flag Photo', 'POT', 'Team & Contract', 'Height', 'Weight', 'foot', 'Growth', 'Joined', 'Loan Date End', 'Value', 'Wage', 'Release Clause', 'Contract', 'Attacking', 'Crossing', 'Finishing', 'Heading Accuracy', 'Short Passing', 'Volleys', 'Skill', 'Dribbling', 'Curve', 'FK Accuracy', 'Long Passing', 'Ball Control', 'Movement', 'Acceleration', 'Sprint Speed', 'Agility', 'Reactions', 'Balance', 'Power', 'Shot Power', 'Jumping', 'Stamina', 'Strength', 'Long Shots', 'Mentality', 'Aggression', 'Interceptions', 'Positioning', 'Vision', 'Penalties', 'Composure', 'Defending', 'Marking', 'Standing Tackle', 'Sliding Tackle', 'Goalkeeping', 'GK Diving', 'GK Handling', 'GK Kicking', 'GK Positioning', 'GK Reflexes', 'Total Stats', 'Base Stats', 'W/F', 'SM', 'A/W', 'D/W', 'IR', 'PAC', 'SHO', 'PAS', 'DRI', 'DEF', 'PHY', 'Hits', 'LS', 'ST', 'RS', 'LW', 'LF', 'CF', 'RF', 'RW', 'LAM', 'CAM', 'RAM',
# ...

# %%
# Which columns had no missing values?

# %%
no_nulls = set(data.columns[np.sum(data.isnull()) == 0]) #Provide a set of columns with 0 missing values.
print(no_nulls)
# Out:
# {'LWB', 'LAM', 'Attacking', 'Base Stats', 'Short Passing', 'Dribbling', 'Weight', 'Flag Photo', 'GK', 'GK Positioning', 'FK Accuracy', 'OVA', 'Long Shots', 'PAC', 'Player Photo', 'DRI', 'RDM', 'Value', 'Team & Contract', 'DEF', 'Contract', 'ST', 'LW', 'Power', 'Marking', 'GK Kicking', 'Name', 'RS', 'RB', 'RWB', 'Goalkeeping', 'IR', 'CDM', 'Strength', 'Growth', 'CF', 'BOV', 'CAM', 'Finishing', 'RAM', 'LF', 'Stamina', 'GK Reflexes', 'RCM', 'Defending', 'Hits', 'Long Passing', 'BP', 'LB', 'Heading Accuracy', 'foot', 'Shot Power', 'Acceleration', 'LCM', 'LDM', 'Wage', 'RW', 'SM', 'POT', 'Mentality', 'Nationality', 'Sprint Speed', 'PHY', 'CM', 'CB', 'RCB', 'Skill', 'Crossing', 'Release Clause', 'Gender', 'SHO', 'LCB', 'RM', 'Aggression', 'ID', 'Age', 'GK Handling', 'LS', 'PAS', 'Penalties', 'Movement', 'LM', 'RF', 'Total Stats', 'Ball Control', 'Standing Tackle', 'GK Diving', 'Reactions', 'W/F', 'Height'}

# %%
#  Which columns have the most missing values?

# %%
data.describe().apply(lambda x: round(x,2))
# Out:
#               ID       Age       OVA       BOV       POT    Growth  Attacking  \
# count   17125.00  17125.00  17125.00  17125.00  17125.00  17125.00   17125.00
# mean   219388.72     25.27     66.97     67.90     72.49      5.52     258.54
# std     37499.20      4.94      6.86      6.64      5.77      5.79      72.26
# min         2.00     16.00     38.00     42.00     47.00     -1.00      33.00
# 25%    204082.00     21.00     62.00     64.00     69.00      0.00     232.00
# 50%    228961.00     25.00     67.00     68.00     72.00      4.00     271.00
# 75%    243911.00     29.00     72.00     72.00     76.00      9.00     306.00
# max    259105.00     53.00     93.00     93.00     95.00     26.00     437.00
#
#        Crossing  Finishing  Heading Accuracy  Short Passing   Volleys  \
# count  17125.00   17125.00          17125.00       17125.00  17067.00
# mean      51.62      47.96             53.60          60.51     45.01
# ...

# %%
#  Which columns have the most missing values?

# %%
most_25_missing_cols = set(data.columns[np.sum(data.isnull())/data.shape[0] > .25]) #Provide a set of columns with more than 25% of the values missing
most_50_missing_cols = set(data.columns[np.sum(data.isnull())/data.shape[0] > .50]) #Provide a set of columns with more than 50% of the values missing
most_75_missing_cols = set(data.columns[np.sum(data.isnull())/data.shape[0] > .75]) #Provide a set of columns with more than 75% of the values missing

print('The columns with more than 25% of the values: ', most_25_missing_cols)
print('The columns with more than 50% of the values: ', most_50_missing_cols)
print('The columns with more than 75% of the values: ', most_75_missing_cols)
# Out:
# The columns with more than 25% of the values:  {'Loan Date End'}
# The columns with more than 50% of the values:  {'Loan Date End'}
# The columns with more than 75% of the values:  {'Loan Date End'}

# %%
data = data.drop(['Loan Date End'], axis = 1)

data.columns
print(data.columns.tolist())
# Out:
# ['ID', 'Name', 'Age', 'OVA', 'Nationality', 'Club', 'BOV', 'BP', 'Position', 'Player Photo', 'Club Logo', 'Flag Photo', 'POT', 'Team & Contract', 'Height', 'Weight', 'foot', 'Growth', 'Joined', 'Value', 'Wage', 'Release Clause', 'Contract', 'Attacking', 'Crossing', 'Finishing', 'Heading Accuracy', 'Short Passing', 'Volleys', 'Skill', 'Dribbling', 'Curve', 'FK Accuracy', 'Long Passing', 'Ball Control', 'Movement', 'Acceleration', 'Sprint Speed', 'Agility', 'Reactions', 'Balance', 'Power', 'Shot Power', 'Jumping', 'Stamina', 'Strength', 'Long Shots', 'Mentality', 'Aggression', 'Interceptions', 'Positioning', 'Vision', 'Penalties', 'Composure', 'Defending', 'Marking', 'Standing Tackle', 'Sliding Tackle', 'Goalkeeping', 'GK Diving', 'GK Handling', 'GK Kicking', 'GK Positioning', 'GK Reflexes', 'Total Stats', 'Base Stats', 'W/F', 'SM', 'A/W', 'D/W', 'IR', 'PAC', 'SHO', 'PAS', 'DRI', 'DEF', 'PHY', 'Hits', 'LS', 'ST', 'RS', 'LW', 'LF', 'CF', 'RF', 'RW', 'LAM', 'CAM', 'RAM', 'LM', 'LCM', 'CM
# ...

# %%
#Overall Score players

# %%
best_players = data.sort_values(['OVA'],ascending=[False]).head(100)

selected = best_players[['Name', 'OVA']]
selected.head(20)
# Out:
#                    Name  OVA
# 752            L. Messi   93
# 142   Cristiano Ronaldo   92
# 2871       K. De Bruyne   91
# 2287     R. Lewandowski   91
# 2650          Neymar Jr   91
# 3665           J. Oblak   91
# 2790      M. ter Stegen   90
# 9331          K. Mbappé   90
# 5777            Alisson   90
# 4166        V. van Dijk   90
# 5109           M. Salah   90
# 5030            S. Mané   90
# 2745        T. Courtois   89
# 662           S. Agüero   89
# 3630           Casemiro   89
# 681        Sergio Ramos   89
# 1010           M. Neuer   89
# 946          K. Benzema   89
# 4049        R. Sterling   88
# 1800          E. Hazard   88

# %%
#Sort the Players by Overall Score and No of Hits

# %%
best_players = data.sort_values(['OVA', 'Hits'],ascending=[False, False]).head(100)
selected = best_players[['Name', 'OVA', 'Hits']]
topdata = selected.head(3)
topdata.head(3)
# Out:
#                    Name  OVA Hits
# 752            L. Messi   93  830
# 142   Cristiano Ronaldo   92  750
# 2650          Neymar Jr   91  546

# %%
top3 = [['L. Messi', 93, 830], ['Cristiano Ronaldo', 92, 750], ['Neymar Jr', 91, 546]]
top3data = pd.DataFrame(top3, columns=["Name","OVA","Hits"])
print(top3data)
# Out:
#                 Name  OVA  Hits
# 0           L. Messi   93   830
# 1  Cristiano Ronaldo   92   750
# 2          Neymar Jr   91   546

# %%
for column in num.columns:
    sns.distplot(data[column])
    plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_7400/3868662353.py in <module>
# ----> 1 for column in num.columns:
#       2     sns.distplot(data[column])
#       3     plt.show()
#
# NameError: name 'num' is not defined

# %%
#covariance visualization

# %%
#Plot a Bar Chart for the Top 3 Plyers and Show their Overall Score and No of Hits
model = LinearRegression()
model.fit( #fill, fill )

# %%
''' Plot a Bar Chart for the Top 3 Plyers and Show their Overall Score and No of Hits'''
top3data.plot(x='Name', y=['OVA', 'Hits'], kind='bar');

# %%
#HEATMAP
mask = np.zeros_like(data.corr())
mask[np.triu_indices_from(mask)] = True # optional, to hide repeat half of the matrix
fig, ax = plt.subplots(figsize=(10, 8))
ax = sns.heatmap(data.corr(), mask=mask, annot=True)
plt.show()

# from this you can remove multicolinearity > 0.9 with no worry...
## ... > 0.75 is better to check with the model metrics to be sure
### when removing, keep the ones that have the highest correlation with target

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_7400/1414350166.py in <module>
# ----> 1 X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)
#
# NameError: name 'X' is not defined

# %%
''' 
    Find the Oldest and Youngest Players
'''

oldest = data.sort_values('Age',ascending=False).head(1)
print(oldest)

youngest = data.sort_values('Age',ascending=True).head(1)
print(youngest)

age = [['K. Miura', 53], ['T. Gulliksen', 16]]
agedata = pd.DataFrame(age, columns=["Name","Age",])

agedata.plot(x="Name", y="Age", kind="bar");
plt.show();
# Out:
#            ID      Name  Age  OVA Nationality         Club  BOV  BP Position  \
# 15737  254704  K. Miura   53   59       Japan  Yokohama FC   60  CF       ST
#
#                                             Player Photo  \
# 15737  https://cdn.sofifa.com/players/254/704/20_120.png
#
#                                               Club Logo  \
# 15737  https://cdn.sofifa.com/teams/113197/light_60.png
#
#                                 Flag Photo  POT          Team & Contract  \
# 15737  https://cdn.sofifa.com/flags/jp.png   59  Yokohama FC 2005 ~ 2021
#
#       Height  Weight   foot  Growth       Joined Value  Wage Release Clause  \
# 15737  5'10"  159lbs  Right       0  Jul 1, 2005    €0  €850             €0
#
#           Contract  Attacking  Crossing  Finishing  Heading Accuracy  \
# 15737  2005 ~ 2021        289        44         66                56
#
#        Short Passing  Volleys  Skill  Dribbling  Curve  FK Accuracy  \
# ...

# %%
df['range'].str.replace(“\n”,’’.)

# %%
df['range'].str.replace(',','-')
df['range'].str.replace(“\n”,’’.)
file1[“Height].str.replace(“\n”,’’.)

# %%
data = data.set_index('id') 
data.head()

# %%
cols_lst = ['name', 'hits']
data[cols_lst]

# %%
data.select_dtypes("object")
